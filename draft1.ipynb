# %%
import numpy as np
import pandas as pd
"""
credit 是演职人员
keyword 是电影特征表



"""
# Out:
# '\ncredit 是演职人员\nkeyword 是电影特征表\n\n\n\n'

# %%
credits_df = pd.read_csv("archive\credits.csv")
movies_df = pd.read_csv("archive\movies.csv")
movies_meta_df=pd.read_csv("archive\movies_metadata.csv")
# Out:
# C:\Users\ethan\AppData\Local\Temp\ipykernel_14736\2680673937.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_meta_df=pd.read_csv("archive\movies_metadata.csv")

# %%
movies_df.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   10-12-2009  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
movies_df=credits_df.merge(movies_df,on="title")

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4808 entries, 0 to 4807
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_id              4808 non-null   int64
#  1   title                 4808 non-null   object
#  2   cast                  4808 non-null   object
#  3   crew                  4808 non-null   object
#  4   budget                4808 non-null   int64
#  5   genres                4808 non-null   object
#  6   homepage              1713 non-null   object
#  7   id                    4808 non-null   int64
#  8   keywords              4808 non-null   object
#  9   original_language     4808 non-null   object
#  10  original_title        4808 non-null   object
#  11  overview              4805 non-null   object
#  12  popularity            4808 non-null   float64
#  13  production_companies  4808 non-null   object
#  14  production_countries  4808 non-null   object
# ...

# %%
movies_df=movies_df[["id"]]
movies_df
# Out:
#           id
# 0      19995
# 1        285
# 2     206647
# 3      49026
# 4      49529
# ...      ...
# 4803    9367
# 4804   72766
# 4805  231617
# 4806  126186
# 4807   25975
#
# [4808 rows x 1 columns]

# %%
movies_meta_df.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
testa=pd.DataFrame({"A":[1,2,3],"B":[1,2,3]})
np.asarray(testa)
testa[["A"]]
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
print(np.array(testa))
print()
# Out:
# [[1 1]
#  [2 2]
#  [3 3]]

# %%
data = [['Google',10],['Runoob',12],['Wiki',13]]

df = pd.DataFrame(data,columns=['Site',"lo"],dtype=float) #正常搜索需要使用类似字典，每列一个字典，使用df[keys]然后获得列

x=df.groupby("Site")
df
print(x)
# Out:
# ...
# C:\Users\ethan\AppData\Local\Temp\ipykernel_14736\4101151136.py:3: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   df = pd.DataFrame(data,columns=['Site',"lo"],dtype=float) #正常搜索需要使用类似字典，每列一个字典，使用df[keys]然后获得列

# %%
boolean=[True,False]
gender=["男","女"]
color=["white","black","yellow"]
data=pd.DataFrame({
    "height":np.random.randint(150,190,100),
    "weight":np.random.randint(40,90,100),
    "smoker":[boolean[x] for x in np.random.randint(0,2,100)],
    "gender":[gender[x] for x in np.random.randint(0,2,100)],
    "age":np.random.randint(15,90,100),
    "color":[color[x] for x in np.random.randint(0,len(color),100) ]
}
)

# %%
def search(df,**kwargs):
    newp=df.copy()
    for i in kwargs:
        newp=newp.groupby(i).get_group(kwargs[i])
    return newp

# %%
datamp=search(data,color="black",smoker=False,gender="男")
print(datamp)
# Out:
#     height  weight  smoker gender  age  color
# 3      176      82   False      男   47  black
# 18     158      42   False      男   83  black
# 62     165      88   False      男   82  black
# 72     184      71   False      男   62  black
# 74     158      60   False      男   71  black
# 82     151      50   False      男   89  black
# 89     185      72   False      男   35  black
